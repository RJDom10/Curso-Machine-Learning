# %% [markdown]
# <a href="https://colab.research.google.com/github/RJDom10/Curso-Machine-Learning/blob/main/notebooks/01_preprocesamiento/04_Ejercicios_Practicos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Preprocesamiento de Datos
#
# **Curso de Machine Learning** | Modulo 1: Preparacion de Datos
#
# ---
#
# ## Introduccion
#
# Este cuaderno esta disenado para evaluar y consolidar el conocimiento adquirido durante las primeras tres sesiones del modulo de Preprocesamiento de Datos.
#
# Los ejercicios presentados a continuacion abarcan:
# 1. Limpieza y Normalizacion de Datos.
# 2. Integracion de Datos mediante Tablas Pivote.
# 3. Deteccion de Valores Atipicos (Outliers), Reduccion de Dimensionalidad e Ingenieria de Caracteristicas.
#
# Se requiere completar los bloques de codigo indicados. Asegurese de importar las bibliotecas necesarias conforme se desarrollen los ejercicios.

# %% [markdown]
# ---
#
# ## Seccion 1: Preprocesamiento Basico y Normalizacion
#
# Para esta seccion utilizaremos el conjunto de datos de aprobacion crediticia (`creditApproval_dataset.csv`).

# %%
import pandas as pd
import numpy as np

file_path_credit = '../../data/creditApproval_dataset.csv'
df_credit = pd.read_csv(file_path_credit)
df_credit.head()

# %% [markdown]
# ### Ejercicio 1.1: Normalizacion Z-Score
#
# En el primer cuaderno revisamos la normalizacion Min-Max. Su tarea ahora es aplicar la normalizacion Z-Score (Estandarizacion) empleando la biblioteca `scikit-learn`.
#
# **Instrucciones:**
# 1. Seleccione unicamente las columnas numericas del DataFrame `df_credit`.
# 2. Instancie el objeto `StandardScaler` de `sklearn.preprocessing`.
# 3. Aplique la transformacion sobre las columnas numericas y reemplace los valores originales en una copia del DataFrame.
# 4. Muestre las estadisticas descriptivas (media y desviacion estandar) resultantes para confirmar que la media es aproximadamente 0 y la desviacion estandar es 1.

# %%
# Inserte su codigo aqui

# from sklearn.preprocessing import StandardScaler
# df_zscore = df_credit.copy()
# numeric_cols = ...
# scaler = StandardScaler()
# df_zscore[numeric_cols] = ...
# df_zscore[numeric_cols].describe().round(3)

# %% [markdown]
# ---
#
# ## Seccion 2: Integracion de Datos y Tablas Pivote
#
# Para esta seccion utilizaremos la base de datos de casos historicos de COVID-19 (`covid19WW_2021.csv`).

# %%
file_path_covid = '../../data/covid19WW_2021.csv'
df_covid = pd.read_csv(file_path_covid)
df_covid.head()

# %% [markdown]
# ### Ejercicio 2.1: Casos Confirmados Acumulados por Dia y Pais
#
# Calcule los casos confirmados acumulados estructurando los datos en formato de serie de tiempo multivariada.
#
# **Instrucciones:**
# 1. Transforme la columna `Date` al formato de fecha estandar (`pd.to_datetime`).
# 2. Utilice `pd.pivot_table` para generar un DataFrame donde el indice sean las fechas (`Date`), las columnas sean los paises (`Country`), y los valores sean la suma (`np.sum`) de los casos confirmados (`Confirmed`).

# %%
# Inserte su codigo aqui

# df_covid['Date'] = pd.to_datetime(df_covid['Date'])
# df_series_tiempo = pd.pivot_table( ... )
# df_series_tiempo.head()

# %% [markdown]
# ### Ejercicio 2.2: Agregacion de Mortalidad por Mes y Pais
#
# Cambie la granularidad de la serie de tiempo para analizar la mortalidad mensual.
#
# **Instrucciones:**
# 1. Cree una columna denominada `YearMonth` empleando `.dt.to_period('M')` sobre la fecha.
# 2. Genere una tabla pivote que muestre el total de muertes (`Deaths`) empleando `np.sum`. El indice debe ser el Pais y las columnas el Año-Mes.
# 3. Imprima los primeros 10 registros del DataFrame resultante.

# %%
# Inserte su codigo aqui

# df_covid['YearMonth'] = df_covid['Date'].dt.to_period('M')
# df_mortalidad_mensual = pd.pivot_table( ... )
# df_mortalidad_mensual.head(10)

# %% [markdown]
# ### Ejercicio 2.3: Analisis de Picos Epidemicos
#
# Identifique el dia con el mayor numero de casos reportados para un subconjunto de paises.
#
# **Instrucciones:**
# 1. Utilizando el DataFrame generado en el Ejercicio 2.1.
# 2. Extraiga las columnas correspondientes a `['Mexico', 'Italy', 'US', 'India']`.
# 3. Emplee la funcion `.idxmax()` para determinar y mostrar la fecha en la que cada uno de estos paises alcanzo su maximo historico de casos.

# %%
# Inserte su codigo aqui

# paises_objetivo = ['Mexico', 'Italy', 'US', 'India']
# picos = df_series_tiempo[paises_objetivo].idxmax()
# print("Fechas con mayor numero de casos confirmados:")
# print(picos)

# %% [markdown]
# ---
#
# ## Seccion 3: Preprocesamiento Avanzado
#
# Regresaremos al conjunto de datos de aprobacion crediticia (`df_credit`) para evaluar los conceptos de Deteccion de Anomalias y Reduccion de Datos.

# %% [markdown]
# ### Ejercicio 3.1: Deteccion de Outliers mediante IQR
#
# Implemente la deteccion de valores atipicos univariados.
#
# **Instrucciones:**
# 1. Convierta la columna `A8` a formato numerico, descartando los valores nulos (`NaN`).
# 2. Calcule el primer cuartil (Q1) y el tercer cuartil (Q3).
# 3. Determine el Rango Intercuartilico (IQR) y defina los limites inferior y superior.
# 4. Cuente e imprima el numero de outliers identificados en la variable `A8`.

# %%
# Inserte su codigo aqui

# data_a8 = pd.to_numeric(df_credit['A8'], errors='coerce').dropna()
# Q1 = ...
# Q3 = ...
# IQR = ...
# lower_bound = ...
# upper_bound = ...
# outliers = data_a8[(data_a8 < lower_bound) | (data_a8 > upper_bound)]
# print(f"Outliers en A8: {len(outliers)}")

# %% [markdown]
# ### Ejercicio 3.2: Reduccion de Dimensionalidad (PCA)
#
# Implemente el Analisis de Componentes Principales reduciendo el umbral de varianza.
#
# **Instrucciones:**
# 1. Extraiga las columnas numericas del DataFrame `df_credit`, impute sus valores nulos con la mediana y estandarice los datos (puede reciclar la logica vista en clase).
# 2. Aplique PCA configurando el modelo para retener exactamente el **90% de la varianza explicada** (`n_components=0.90`).
# 3. Imprima cuantas dimensiones (componentes) fueron necesarias para alcanzar este 90%.

# %%
# Inserte su codigo aqui

# from sklearn.decomposition import PCA
# from sklearn.impute import SimpleImputer
# from sklearn.preprocessing import StandardScaler

# numeric_df = df_credit.select_dtypes(include=[np.number]).dropna(axis=1, how='all')
# imputer = SimpleImputer(strategy='median')
# scaled_data = StandardScaler().fit_transform(imputer.fit_transform(numeric_df))

# pca_90 = PCA(n_components=0.90)
# data_pca_90 = pca_90.fit_transform(scaled_data)
# print(f"Componentes necesarios para el 90% de varianza: {data_pca_90.shape[1]}")

# %% [markdown]
# ### Ejercicio 3.3: Ingenieria de Caracteristicas (Polinomios)
#
# Genere expansiones polinomiales para incrementar la representatividad numerica.
#
# **Instrucciones:**
# 1. Utilizando los datos estandarizados generados en el Paso 3.2, seleccione las primeras 3 variables (columnas 0, 1 y 2).
# 2. Aplique `PolynomialFeatures` con un grado de polinomio igual a 3 (`degree=3`).
# 3. Imprima las dimensiones del arreglo original de 3 variables y las dimensiones del nuevo arreglo polinomial.

# %%
# Inserte su codigo aqui

# from sklearn.preprocessing import PolynomialFeatures
# X_subset = scaled_data[:, :3]
# poly_3 = PolynomialFeatures(degree=3, include_bias=False)
# X_poly_3 = poly_3.fit_transform(X_subset)
# print(f"Dimension original: {X_subset.shape[1]}")
# print(f"Dimension tras expansion polinomica de grado 3: {X_poly_3.shape[1]}")
